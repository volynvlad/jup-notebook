# %%
import tensorflow as tf
print("tf version - {}".format(tf.__version__))
from tensorflow import keras
import numpy as np
print("numpy version - {}".format(np.__version__))
# Out:
# tf version - 2.0.0
# numpy version - 1.16.1

# %% [markdown]
# ### get data

# %%
data = keras.datasets.imdb

# %%
(train_data, train_labels), (test_data, test_labels) = data.load_data(num_words=88_000)

# %%
train_data.shape, test_data.shape
# Out:
# ((25000,), (25000,))

# %%
print(test_data[0], sep=',')
# Out:
# [1, 591, 202, 14, 31, 6, 717, 10, 10, 18142, 10698, 5, 4, 360, 7, 4, 177, 5760, 394, 354, 4, 123, 9, 1035, 1035, 1035, 10, 10, 13, 92, 124, 89, 488, 7944, 100, 28, 1668, 14, 31, 23, 27, 7479, 29, 220, 468, 8, 124, 14, 286, 170, 8, 157, 46, 5, 27, 239, 16, 179, 15387, 38, 32, 25, 7944, 451, 202, 14, 6, 717]

# %%
word_index = data.get_word_index()

# %%
word_index = {k:(v+3) for k, v in word_index.items()}

# %%
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2
word_index["<UNUSED>"] = 3

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
def decode_review(text):
    return " ".join([reverse_word_index.get(i, "?") for i in text])

# %%
decode_review(test_data[0])
# Out:
# "<START> please give this one a miss br br kristy swanson and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite lacklustre so all you madison fans give this a miss"

# %%
print(len(test_data[1]), len(test_data[2]))
# Out:
# 260 603

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index["<PAD>"], padding="post", maxlen=250)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index["<PAD>"], padding="post", maxlen=250)

# %%
print(len(test_data[1]), len(test_data[2]))
# Out:
# 250 250

# %% [markdown]
# ### build the model

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(88000, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          1408000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,408,289
# Trainable params: 1,408,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
x_val = train_data[:10_000]
x_train = train_data[10_000:]
y_val = train_labels[:10_000]
y_train = train_labels[10_000:]

# %% [markdown]
# ### train the model

# %%
epochs = 40
batch_size=512

# %%
fit_model = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size,
                     validation_data=(x_val, y_val), verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 2s 100us/sample - loss: 0.6919 - accuracy: 0.5437 - val_loss: 0.6896 - val_accuracy: 0.6801
# Epoch 2/40
# 15000/15000 [==============================] - 1s 48us/sample - loss: 0.6856 - accuracy: 0.6917 - val_loss: 0.6808 - val_accuracy: 0.7094
# Epoch 3/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.6715 - accuracy: 0.7567 - val_loss: 0.6629 - val_accuracy: 0.7340
# Epoch 4/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.6458 - accuracy: 0.7782 - val_loss: 0.6347 - val_accuracy: 0.7828
# Epoch 5/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.6078 - accuracy: 0.8117 - val_loss: 0.5959 - val_accuracy: 0.8002
# Epoch 6/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.5577 - accuracy: 0.8337 - val_loss: 0.5492 - val_accuracy: 0.8137
# Epoch 7/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.5022 - accuracy: 0.8515 - val_loss: 0.5022 - val_accuracy: 0.8255
# Epoch 8/40
# 15000/15000 [==============================] - 1s 48us/sample - loss: 0.4475 - accuracy: 0.8693 - val_loss: 0.4596 - val_accuracy: 0.8380
# Epoch 9/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.3981 - accuracy: 0.8853 - val_loss: 0.4225 - val_accuracy: 0.8497
# Epoch 10/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.3548 - accuracy: 0.8975 - val_loss: 0.3920 - val_accuracy: 0.8597
# Epoch 11/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.3181 - accuracy: 0.9063 - val_loss: 0.3686 - val_accuracy: 0.8640
# Epoch 12/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.2871 - accuracy: 0.9153 - val_loss: 0.3483 - val_accuracy: 0.8716
# Epoch 13/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.2602 - accuracy: 0.9217 - val_loss: 0.3326 - val_accuracy: 0.8755
# Epoch 14/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.2373 - accuracy: 0.9288 - val_loss: 0.3204 - val_accuracy: 0.8779
# Epoch 15/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.2165 - accuracy: 0.9374 - val_loss: 0.3111 - val_accuracy: 0.8791
# Epoch 16/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.1987 - accuracy: 0.9427 - val_loss: 0.3018 - val_accuracy: 0.8825
# Epoch 17/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.1826 - accuracy: 0.9485 - val_loss: 0.2949 - val_accuracy: 0.8845
# Epoch 18/40
# 15000/15000 [==============================] - 1s 57us/sample - loss: 0.1682 - accuracy: 0.9523 - val_loss: 0.2906 - val_accuracy: 0.8850
# Epoch 19/40
# 15000/15000 [==============================] - 1s 53us/sample - loss: 0.1552 - accuracy: 0.9588 - val_loss: 0.2853 - val_accuracy: 0.8868
# Epoch 20/40
# 15000/15000 [==============================] - 1s 54us/sample - loss: 0.1432 - accuracy: 0.9628 - val_loss: 0.2820 - val_accuracy: 0.8872
# Epoch 21/40
# 15000/15000 [==============================] - 1s 56us/sample - loss: 0.1324 - accuracy: 0.9669 - val_loss: 0.2807 - val_accuracy: 0.8867
# Epoch 22/40
# 15000/15000 [==============================] - 1s 53us/sample - loss: 0.1227 - accuracy: 0.9700 - val_loss: 0.2778 - val_accuracy: 0.8875
# Epoch 23/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.1137 - accuracy: 0.9729 - val_loss: 0.2785 - val_accuracy: 0.8862
# Epoch 24/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.1060 - accuracy: 0.9761 - val_loss: 0.2758 - val_accuracy: 0.8881
# Epoch 25/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.0981 - accuracy: 0.9788 - val_loss: 0.2754 - val_accuracy: 0.8897
# Epoch 26/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.0915 - accuracy: 0.9807 - val_loss: 0.2759 - val_accuracy: 0.8890
# Epoch 27/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.0849 - accuracy: 0.9831 - val_loss: 0.2759 - val_accuracy: 0.8889
# Epoch 28/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.0794 - accuracy: 0.9848 - val_loss: 0.2771 - val_accuracy: 0.8896
# Epoch 29/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.0736 - accuracy: 0.9864 - val_loss: 0.2778 - val_accuracy: 0.8895
# Epoch 30/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.0687 - accuracy: 0.9873 - val_loss: 0.2789 - val_accuracy: 0.8894
# Epoch 31/40
# 15000/15000 [==============================] - 1s 52us/sample - loss: 0.0645 - accuracy: 0.9885 - val_loss: 0.2806 - val_accuracy: 0.8896
# Epoch 32/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.0600 - accuracy: 0.9900 - val_loss: 0.2825 - val_accuracy: 0.8887
# Epoch 33/40
# 15000/15000 [==============================] - 1s 53us/sample - loss: 0.0560 - accuracy: 0.9905 - val_loss: 0.2861 - val_accuracy: 0.8886
# Epoch 34/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.0524 - accuracy: 0.9918 - val_loss: 0.2872 - val_accuracy: 0.8887
# Epoch 35/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.0490 - accuracy: 0.9921 - val_loss: 0.2905 - val_accuracy: 0.8882
# Epoch 36/40
# 15000/15000 [==============================] - 1s 50us/sample - loss: 0.0460 - accuracy: 0.9930 - val_loss: 0.2922 - val_accuracy: 0.8877
# Epoch 37/40
# 15000/15000 [==============================] - 1s 49us/sample - loss: 0.0430 - accuracy: 0.9939 - val_loss: 0.2947 - val_accuracy: 0.8884
# Epoch 38/40
# 15000/15000 [==============================] - 1s 51us/sample - loss: 0.0405 - accuracy: 0.9941 - val_loss: 0.2965 - val_accuracy: 0.8883
# Epoch 39/40
# 15000/15000 [==============================] - 1s 58us/sample - loss: 0.0380 - accuracy: 0.9947 - val_loss: 0.3001 - val_accuracy: 0.8871
# Epoch 40/40
# 15000/15000 [==============================] - 1s 54us/sample - loss: 0.0358 - accuracy: 0.9953 - val_loss: 0.3010 - val_accuracy: 0.8879

# %%
results = model.evaluate(test_data, test_labels)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
results
# Out:
# [0.33821725542545317, 0.87068]

# %%
test_review = test_data[0]
predict = model.predict([test_review])
print("Review: {}".format(decode_review(test_review)))
print("Prediction: {}".format(predict[0]))
print("Actual: {}".format(test_labels[0]))
# Out:
# Review: <START> please give this one a miss br br kristy swanson and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite lacklustre so all you madison fans give this a miss <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Prediction: [0.]
# Actual: 0

# %%
test_review = test_data[10]
predict = model.predict([test_review])
print("Review: {}".format(decode_review(test_review)))
print("Prediction: {}".format(predict[10]))
print("Actual: {}".format(test_labels[10]))
# Out:
# Review: <START> inspired by hitchcock's strangers on a train concept of two men swapping murders in exchange for getting rid of the two people messing up their lives throw momma from the train is an original and very inventive comedy take on the idea it's a credit to danny devito that he both wrote and starred in this minor comedy gem br br anne ramsey is the mother who inspires the film's title and it's understandable why she gets under the skin of danny devito with her sharp tongue and relentlessly putting him down for any minor infraction billy crystal is the writer who's wife has stolen his book idea and is now being lionized as a great new author even appearing on the oprah show to in adulation he should be enjoying thus devito gets the idea of swapping murders to rid themselves of these nuisance factors br br of course everything and anything can happen when writer carl reiner lets his imagination roam with unending ideas for how the plot develops and it's amusing all the way through providing plenty of laughs and chuckles along the way as well as a good deal of suspense br br for devotees of black comedy this one is guaranteed to please <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Prediction: [1.]
# Actual: 1

# %% [markdown]
# ### Save/Load the model

# %%
name = "text_classification_model.h5"

# %%
model.save(name)

# %%
model = keras.models.load_model(name)

# %% [markdown]
# ### Run the model on own review

# %%
def review_encode(s):
    encoded = [1]
    
    for word in s:
        if word.lower() in word_index:
            encoded.append(word_index[word.lower()])
        else:
            encoded.append(2)
    return encoded

# %% [raw]
# 0 - negative review
# 1 - positive review

# %%
with open("review.txt", encoding="utf-8") as f:
    for line in f.readlines():
        nline = line.replace(",","").replace(".","").replace("(","").replace(")","").replace(":","").replace("\"", "").strip(" ")
        encode = review_encode(nline)
        encode = keras.preprocessing.sequence.pad_sequences([encode], value=word_index["<PAD>"], padding="post", maxlen=250)
        predict = model.predict(encode)
        print(line)
        print(encode)
        print(predict[0])
# Out:
# Most of the time movies are anticipated like this they end up falling short, way short. Joker is the first time I was more than happy with the hype. Please ignore the complaints of "pernicious violence" as they are embarrassing to say the least. We haven't seen a comic movie this real before. If we ever "deserved" a better class of criminal - Phillips and Phoenix have delivered. This is dark, Joker IS dark and you will fall in love with the villain as you should. The bad guys are always more romantic anyway.
# [[   2  590  963  963 3363    2    6    2 1148 1604 1983   13 1148    2
#   1983 1604 1964   13  963    2  830 2023   13  590    2 1479  963    6
#   2014    2  503  963 1209 1604 1479  963    2   13 1209    2 1992  963
#      2  963 1964  963 1479    2 1095  963  590  963 1479 1964  963 1095
#      2    6    2  503  963  830  830  963 1479    2 1148 2014    6  590
#    590    2 1604 1209    2 1148 1479   13 1983   13 3363    6 2014    2
#      2    2 1657 2023   13 2014 2014   13 1657  590    2    6 3363 1095
#      2 1657 2023 1604  963 3363   13 1745    2 2023    6 1964  963    2
#   1095  963 2014   13 1964  963 1479  963 1095    2  830 2023   13  590
#      2   13  590    2 1095    6 1479 2295    2 1468 1604 2295  963 1479
#      2   13  590    2 1095    6 1479 2295    2    6 3363 1095    2 5135
#   1604 1206    2 1992   13 2014 2014    2 1209    6 2014 2014    2   13
#   3363    2 2014 1604 1964  963    2 1992   13  830 2023    2  830 2023
#    963    2 1964   13 2014 2014    6   13 3363    2    6  590    2 5135
#   1604 1206    2  590 2023 1604 1206 2014 1095    2  830 2023  963    2
#    503    6 1095    2 1331 1206 5135  590    2    6 1479  963    2    6
#   2014 1992    6 5135  590    2 1983 1604 1479  963    2 1479 1604 1983
#      6 3363  830   13 1148    2    6 3363 5135 1992    6 5135]]
# [5.9866685e-05]
